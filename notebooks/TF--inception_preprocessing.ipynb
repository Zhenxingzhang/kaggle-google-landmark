# %%
import numpy as np
import scipy.misc
import tensorflow as tf
import sys
sys.path.append("/data/slim/models/research/slim/")
from preprocessing import inception_preprocessing

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "/data/landmarks/test/000088da12d664db.jpg"

width = 299
height = 299

# with tf.Session() as sess:
image_raw = tf.cast(np.array(scipy.misc.imread(path, flatten=False, mode='RGB')), tf.float32)
image = inception_preprocessing.preprocess_image(image_raw, height, width, is_training=False)

#     img = sess.run(image)
print(img.shape)
plt.imshow(img)
# Out:
# (299, 299, 3)
# /Users/zzhang/.virtualenvs/tf-py2/lib/python2.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys
